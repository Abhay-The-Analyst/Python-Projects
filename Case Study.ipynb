# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv(r"C:\Users\abhay\OneDrive\Desktop\New folder (5)\data science\drive-download-20211129T055036Z-001 (1)\covid19_Confirmed_dataset.csv")
dataframe.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataframe.shape
# Out:
# (266, 104)

# %%
df = dataframe.drop(columns = ["Lat","Long","Province/State"], axis  =1 , inplace = True)

# %%
dataframe
# Out:
#             Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 261         Western Sahara        0        0        0        0        0
# 262  Sao Tome and Principe        0        0        0        0        0
# 263                  Yemen        0        0        0        0        0
# 264                Comoros        0        0        0        0        0
# 265             Tajikistan        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  \
# ...

# %%
Corona_dataset_aggregated = dataframe.groupby("Country/Region").sum()

# %%
Corona_dataset_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
Corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %%
Corona_dataset_aggregated.loc["China"].plot()
Corona_dataset_aggregated.loc["India"].plot()
Corona_dataset_aggregated.loc["Spain"].plot()
plt.legend()

# %%
# calculate a good measure
Corona_dataset_aggregated.loc["China"].plot()
# Out:
# <Axes: >

# %%
Corona_dataset_aggregated.loc["China"][:3].plot()
# Out:
# <Axes: >

# %%
# calculate the first derivated of curve
Corona_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
# max infection
Corona_dataset_aggregated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
Corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
Corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %%
Country = list(Corona_dataset_aggregated.index)
max_infection_rate = []
for c in Country:
    max_infection_rate.append(Corona_dataset_aggregated.loc[c].diff().max())
Corona_dataset_aggregated["Max_infection_rate"]= max_infection_rate

# %%
Corona_dataset_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
# create a new Data frame
corona_data =pd.DataFrame(Corona_dataset_aggregated["Max_infection_rate"])

# %%
corona_data
# Out:
#                     Max_infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %%
# import dataset 2 
happiness_report = pd.read_csv(r"C:\Users\abhay\OneDrive\Desktop\New folder (5)\data science\drive-download-20211129T055036Z-001 (1)\worldwide_happiness_report.csv")

# %%
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
useless_col = ["Overall rank","Score","Generosity","Perceptions of corruption"]
happiness_report.drop(useless_col,axis= 1 , inplace = True)

# %%
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.set_index("Country or region",inplace = True)

# %%
# Join
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report , how = "inner")

# %%
data
# Out:
#              Max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                  29.0           0.960           1.427
# Vietnam                    19.0           0.741           1.346
# Yemen                       5.0           0.287           1.163
# Zambia                      9.0           0.578           1.058
# Zimbabwe                    8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data.corr()
# Out:
#                               Max_infection_rate  GDP per capita  \
# Max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max_infection_rate                                0.078196
# ...

# %%
data
# Out:
#              Max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                  29.0           0.960           1.427
# Vietnam                    19.0           0.741           1.346
# Yemen                       5.0           0.287           1.163
# Zambia                      9.0           0.578           1.058
# Zimbabwe                    8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
#Visulize
x = data["GDP per capita"]
y = data["Max_infection_rate"]
sns.scatterplot(x=x, y=np.log(y)) #log scaling
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rate'>

# %%
sns.regplot(x= x,y =np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rate'>

# %%
x =  data["Social support"]
y = data["Max_infection_rate"]
sns.scatterplot(x=x, y = np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rate'>

# %%
x =  data["Social support"]
y = data["Max_infection_rate"]
sns.regplot(x=x, y = np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rate'>

# %%
x =  data["Social support"]
y = data["Max_infection_rate"]
sns.scatterplot(x=x, y = np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rate'>

# %%
x =  data["Healthy life expectancy"]
y = data["Max_infection_rate"]
sns.regplot(x=x, y = np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rate'>

# %%
x =  data["Freedom to make life choices"]
y = data["Max_infection_rate"]
sns.scatterplot(x=x, y = np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rate'>

# %%
x =  data["Freedom to make life choices"]
y = data["Max_infection_rate"]
sns.regplot(x=x, y = np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rate'>
