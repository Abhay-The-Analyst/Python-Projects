# %%
import pandas as   pd

# %%
df= pd.read_csv(r"C:\Users\abhay\OneDrive\Desktop\New folder (7)\New folder (3)\Car(1).csv.xls").iloc[:,1:]
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8122             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8123         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8124        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8125               Tata Indigo CR4  2013         290000      25000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df = df.drop(columns = "torque")

# %%
df["seats"].value_counts()
# Out:
# seats
# 5.0     6254
# 7.0     1120
# 8.0      235
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: count, dtype: int64

# %%
df["max_power"] = df["max_power"].str.replace("bhp","")

# %%
df["max_power"] = df["max_power"].astype("float32")

# %%
index = []
for i in range (len(df)):
    try : 
        float(df.iloc[i,-2])
    except :
            index.append(i)
print(index)
# Out:
# []

# %%
df = df.drop(index = 868)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df = df.drop(index = 868)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df=  df.reset_index(drop = True)

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8120             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8121         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8122        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8123               Tata Indigo CR4  2013         290000      25000  Diesel
# 8124               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.plot.scatter("max_power" , "selling_price" , c = "green")
plt.gca().yaxis.get_major_formatter().set_scientific(False)

# %%
df["mileage"]= df["mileage"].str.replace("kmpl","")
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8120             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8121         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8122        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8123               Tata Indigo CR4  2013         290000      25000  Diesel
# 8124               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.loc[1,"engine"]
# Out:
# '1498 CC'

# %%
df["engine"]=df["engine"].str.replace("CC" , "")

# %%
index=[]
for i in range (len(df)):
    try:
        float(df.iloc[i,-3])
        
    except:
        index.append(i)
print(index)
# Out:
# [996]

# %%
df = df.drop(index= 996)

# %%
df["engine"] = df["engine"].astype("float32")

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8120             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8121         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8122        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8123               Tata Indigo CR4  2013         290000      25000  Diesel
# 8124               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.reset_index(drop = True)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8119             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8120         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8121        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8122               Tata Indigo CR4  2013         290000      25000  Diesel
# 8123               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df["fuel"].value_counts()
# Out:
# fuel
# Diesel    4401
# Petrol    3629
# CNG         56
# LPG         38
# Name: count, dtype: int64

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             5287
# Second Owner            2103
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %%
df["owner"]= df["owner"].str.replace("Fifth","Fourth & Above Owner")

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             5287
# Second Owner            2103
# Third Owner              555
# Fourth & Above Owner     174
# Name: count, dtype: int64

# %%
f=df["owner"].isin(["Test Drive Car"])
i=df.index[f]
df=df.drop(i)

# %%
import seaborn as sns
sns.violinplot(data= df , x = "selling_price"  , y = "fuel" , color = "red")
# Out:
# <Axes: xlabel='selling_price', ylabel='fuel'>

# %%
df.plot.scatter("km_driven" , "selling_price")
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().xaxis.get_major_formatter().set_scientific(False)

# %%
sns.violinplot(data = df , x= "fuel" , y= "selling_price" )
plt.gca().yaxis.get_major_formatter().set_scientific(False)

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8120             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8121         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8122        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8123               Tata Indigo CR4  2013         290000      25000  Diesel
# 8124               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df["name"]
# Out:
# 0             Maruti Swift Dzire VDI
# 1       Skoda Rapid 1.5 TDI Ambition
# 2           Honda City 2017-2020 EXi
# 3          Hyundai i20 Sportz Diesel
# 4             Maruti Swift VXI BSIII
#                     ...
# 8120               Hyundai i20 Magna
# 8121           Hyundai Verna CRDi SX
# 8122          Maruti Swift Dzire ZDi
# 8123                 Tata Indigo CR4
# 8124                 Tata Indigo CR4
# Name: name, Length: 8119, dtype: object

# %%
def abc(x):
    brand= x.split()[0]
    name = x.split()[1]
    return brand
df["name"] = df["name"].apply(abc)

# %%
df
# Out:
#          name  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8120  Hyundai  2013         320000     110000  Petrol  Individual
# 8121  Hyundai  2007         135000     119000  Diesel  Individual
# 8122   Maruti  2009         382000     120000  Diesel  Individual
# 8123     Tata  2013         290000      25000  Diesel  Individual
# 8124     Tata  2013         290000      25000  Diesel  Individual
#
#      transmission                 owner mileage  engine   max_power  seats
# 0          Manual           First Owner   23.4   1248.0   74.000000    5.0
# ...

# %%
df["name"].value_counts()
# Out:
# name
# Maruti           2445
# Hyundai          1414
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             466
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        185
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               37
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
pd.options.display.float_format="{:.2f}".format 
g= df.groupby("name")
mean = gb["selling_price"].mean()
print(mean)
# Out:
# name
# Ambassador       124000.00
# Ashok            300000.00
# Audi            2319432.35
# BMW             4109916.67
# Chevrolet        273867.48
# Daewoo            77000.00
# Datsun           314599.95
# Fiat             296063.79
# Force            887500.00
# Ford             516682.58
# Honda            593165.52
# Hyundai          458765.51
# Isuzu           1942000.00
# Jaguar          2915464.79
# Jeep            2149612.87
# Kia             1504500.00
# Land            3608333.33
# Lexus           5150000.00
# MG              1783333.33
# Mahindra         623224.06
# Maruti           403163.34
# Mercedes-Benz   2470444.44
# Mitsubishi       817500.00
# Nissan           465407.36
# Opel              68000.00
# Peugeot           57000.00
# Renault          462618.38
# Skoda            607723.77
# Tata             357433.11
# Toyota           959946.67
# Volkswagen       494216.20
# Volvo           3272014.93
# Name: selling_price, dtype: float64
